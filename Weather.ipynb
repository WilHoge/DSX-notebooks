# %%
import requests
import json
import datetime
import pandas
from pandas.io.json import json_normalize

# %%
lat="50.96"
lon="6.97"
startDate="20160601"
endDate="20160630"
r = requests.get("https://api.weather.com/v1/geocode/"+lat+"/"+lon+"/observations/historical.json?units=m&startDate="+startDate+"&endDate="+endDate+"&apiKey=your-apikey")

# %%
res=r.json()
print "Status: ", r.status_code
res
# Out:
# Status:  200
# {u'metadata': {u'expire_time_gmt': 1475059011,
#   u'language': u'en-US',
#   u'latitude': 50.96,
#   u'longitude': 6.97,
#   u'status_code': 200,
#   u'transaction_id': u'1475055411119:1163925426',
#   u'units': u'm',
#   u'version': u'1'},
#  u'observations': [{u'blunt_phrase': None,
#    u'class': u'observation',
#    u'clds': u'BKN',
#    u'day_ind': u'N',
#    u'dewPt': 14,
#    u'expire_time_gmt': 1464740400,
#    u'feels_like': 15,
#    u'gust': None,
#    u'heat_index': 15,
#    u'icon_extd': 2700,
#    u'key': u'EDDK',
#    u'max_temp': None,
#    u'min_temp': None,
#    u'obs_id': u'EDDK',
#    u'obs_name': u'Cologne/Bonn',
#    u'precip_hrly': None,
#    u'precip_total': None,
#    u'pressure': 1002.15,
#    u'pressure_desc': None,
#    u'pressure_tend': None,
#    u'primary_swell_direction': None,
#    u'primary_swell_height': None,
#    u'primary_swell_period': None,
#    u'primary_wave_height': None,
#    u'primary_wave_period': None,
# ...

# %%
df = json_normalize(res['observations'])
df['timestampstr']=df['expire_time_gmt'].map(lambda x: datetime.datetime.utcfromtimestamp(x))
df[['expire_time_gmt','timestampstr','temp','precip_hrly']]
# Out:
#       expire_time_gmt        timestampstr  temp precip_hrly
# 0          1464740400 2016-06-01 00:20:00    15        None
# 1          1464742200 2016-06-01 00:50:00    14        None
# 2          1464744000 2016-06-01 01:20:00    14        None
# 3          1464745800 2016-06-01 01:50:00    14        None
# 4          1464747600 2016-06-01 02:20:00    14        None
# 5          1464749400 2016-06-01 02:50:00    14        None
# 6          1464751200 2016-06-01 03:20:00    14        None
# 7          1464753000 2016-06-01 03:50:00    14        None
# 8          1464754800 2016-06-01 04:20:00    14        None
# 9          1464756600 2016-06-01 04:50:00    14        None
# 10         1464758400 2016-06-01 05:20:00    14        None
# 11         1464760200 2016-06-01 05:50:00    15        None
# 12         1464762000 2016-06-01 06:20:00    14        None
# 13         1464763800 2016-06-01 06:50:00    14        None
# 14         1464765600 2016-06-01 07:20:00    15        None
# ...

# %%
# !pip install ibmdbpy --user --upgrade
# !wget -O $HOME/.local/lib/python2.7/site-packages/ibmdbpy/db2jcc4.jar https://ibm.box.com/shared/static/o9qfkdaoio8hj4c1fs37sz8zhjp77rl2.x
# Out:
# You are using pip version 7.1.0, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already up-to-date: ibmdbpy in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s311-fa50293fbb7b52-f35abee52e83/.local/lib/python2.7/site-packages
# Requirement already up-to-date: future in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s311-fa50293fbb7b52-f35abee52e83/.local/lib/python2.7/site-packages (from ibmdbpy)
# ...
#   Using cached pandas-0.18.1.tar.gz
# ...
#   Using cached numpy-1.11.1.zip
# ...
#   Using cached six-1.10.0-py2.py3-none-any.whl
# Requirement already up-to-date: pypyodbc in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s311-fa50293fbb7b52-f35abee52e83/.local/lib/python2.7/site-packages (from ibmdbpy)
# Requirement already up-to-date: lazy in /gpfs/global_fs01/sym_shared/YPProdSpark/user/s311-fa50293fbb7b52-f35abee52e83/.local/lib/python2.7/site-packages (from ibmdbpy)
# ...

# %%
credentials_1 = {
  'port':'50000',
  'db':'BLUDB',
  'username':'dash5773',
  'ssljdbcurl':'jdbc:db2://dashdb-entry-yp-dal09-09.services.dal.bluemix.net:50001/BLUDB:sslConnection=true;',
  'host':'dashdb-entry-yp-dal09-09.services.dal.bluemix.net',
  'https_url':'https://dashdb-entry-yp-dal09-09.services.dal.bluemix.net:8443',
  'dsn':'DATABASE=BLUDB;HOSTNAME=dashdb-entry-yp-dal09-09.services.dal.bluemix.net;PORT=50000;PROTOCOL=TCPIP;UID=dash5773;PWD=vsCpA74HFWed;',
  'hostname':'dashdb-entry-yp-dal09-09.services.dal.bluemix.net',
  'jdbcurl':'jdbc:db2://dashdb-entry-yp-dal09-09.services.dal.bluemix.net:50000/BLUDB',
  'ssldsn':'DATABASE=BLUDB;HOSTNAME=dashdb-entry-yp-dal09-09.services.dal.bluemix.net;PORT=50001;PROTOCOL=TCPIP;UID=dash5773;PWD=vsCpA74HFWed;Security=SSL;',
  'uri':'db2://dash5773:vsCpA74HFWed@dashdb-entry-yp-dal09-09.services.dal.bluemix.net:50000/BLUDB',
  'password':"""vsCpA74HFWed"""
}

# %%
from ibmdbpy import IdaDataBase, IdaDataFrame

username = credentials_1['username']
password = credentials_1['password']

jdbc = credentials_1['jdbcurl'] + ":user=" + username + ";password=" + password
print(jdbc)

idadb = IdaDataBase(jdbc)
# Out:
# jdbc:db2://dashdb-entry-yp-dal09-09.services.dal.bluemix.net:50000/BLUDB:user=dash5773;password=vsCpA74HFWed

# %%
wt = idadb.as_idadataframe(df[['expire_time_gmt','timestampstr','temp','precip_hrly']], "WEATHER_COLOGNE", True)
# Out:
# Uploading 1440 rows (maxnrow was set to 2000)

# %%
idadb.show_tables()
# Out:
#   TABSCHEMA                                    TABNAME     OWNER TYPE
# 0  DASH5773  Geographic Coordinates of World Locations  DASH5773    T
# 1  DASH5773                             Interest Rates  DASH5773    T
# 2  DASH5773                            WEATHER_COLOGNE  DASH5773    T

# %%
rr = idadb.ida_query('SELECT day(timestamp("timestampstr")) as day, avg("temp") as temp FROM WEATHER_COLOGNE GROUP BY day(timestamp("timestampstr")) ORDER BY DAY')

# %%
rr
# Out:
#     DAY       TEMP
# 0     1  15.687500
# 1     2  18.458333
# 2     3  17.729166
# 3     4  17.520833
# 4     5  18.937500
# 5     6  20.145833
# 6     7  20.541666
# 7     8  18.708333
# 8     9  15.833333
# 9    10  15.875000
# 10   11  17.375000
# 11   12  16.875000
# 12   13  16.375000
# 13   14  15.729166
# 14   15  14.458333
# 15   16  13.854166
# 16   17  14.833333
# 17   18  14.500000
# 18   19  14.208333
# 19   20  15.083333
# 20   21  18.333333
# 21   22  21.250000
# 22   23  25.916666
# 23   24  21.833333
# 24   25  16.041666
# 25   26  14.770833
# 26   27  14.979166
# 27   28  18.104166
# 28   29  18.541666
# 29   30  18.062500
